# %% [markdown]
# <a href="https://colab.research.google.com/github/VictorCastro135/mineria-de-datos-178920/blob/main/Miner%C3%ADa_de_Datos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Minería de Datos

# %% [markdown]
# ## Primer Parcial

# %% [markdown]
# ### Introducción

# %% [markdown]
# #### Conceptos

# %% [markdown]
# La minería de datos el proceso de extraer información útil a partir de una acumulación de datos, a menudo provenientes de un almacén o de una recopilación de data sets vinculados. Las herramientas para minería de datos incluyen potentes capacidades estadísticas, matemáticas y analíticas cuyo propósito principal es examinar grandes data sets para identificar tendencias, patrones y relaciones a fin de dar soporte a la toma de decisiones y planificación fundamentadas.

# %% [markdown]
# #### Ciencia de Datos

# %% [markdown]
# La ciencia de datos es el estudio de datos con el fin de extraer información significativa para empresas. Es un enfoque multidisciplinario que combina principios y prácticas del campo de las matemáticas, la estadística, la inteligencia artificial y la ingeniería de computación para analizar grandes cantidades de datos. Este análisis permite que los científicos de datos planteen y respondan a preguntas como “qué pasó”, “por qué pasó”, “qué pasará” y “qué se puede hacer con los resultados”.

# %%
help(len)
# Out:
# Help on built-in function len in module builtins:
#
# len(obj, /)
#     Return the number of items in a container.

# %%
len("mineria")
# Out:
# 7

# %%
len?

# %%
L = [1,2,3]
L.insert?

# %%
L?

# %%
def square(a):
  """Return the square of a."""
  a**2

# %%
square?

# %%
square??

# %%
len??

# %%
L.append
# Out:
# <function list.append(object, /)>

# %%
L.clear
# Out:
# <function list.clear()>

# %%
L.count
# Out:
# <function list.count(value, /)>

# %%
L.__add__
# Out:
# <method-wrapper '__add__' of list object at 0x7ff57fb5aec0>

# %%
from itertools import count

# %%
import itertools

# %%
*Warning?

# %%
str.*find*?

# %% [markdown]
# IPython Magic Commands

# %%
# El comando mágico %timeit% sirve para evaluar el desempeño en términos de tiempo
# %timeit L = [n ** 2 for n in range(1000)]
# Out:
# 85.3 µs ± 25.2 µs per loop (mean ± std. dev. of 7 runs, 10000 loops each)

# %%
# El comando mágico %%timeit sirve también para evaluar el desempeño, solo que este abarca varias lineas de código en lugar de una
# %%timeit
 L = []
for n in range(1000):
  L.append(n ** 2)
# Out:
# 82.5 µs ± 17.1 µs per loop (mean ± std. dev. of 7 runs, 10000 loops each)

# %%
# %timeit?

# %%
# %%timeit?

# %% [markdown]
# IPython and Shell Commands

# %%
# !ls
# Out:
# sample_data

# %%
# %cd sample_data/
# Out:
# /content/sample_data

# %%
# %ls
# Out:
# anscombe.json*                mnist_test.csv
# california_housing_test.csv   mnist_train_small.csv
# california_housing_train.csv  README.md*

# %%
# !cat README.md
# Out:
# This directory includes a few sample datasets to get you started.
#
# *   `california_housing_data*.csv` is California housing data from the 1990 US
#     Census; more information is available at:
#     https://docs.google.com/document/d/e/2PACX-1vRhYtsvc5eOR2FWNCwaBiKL6suIOrxJig8LcSBbmCbyYsayia_DvPOOBlXZ4CAlQ5nlDD8kTaIDRwrN/pub
#
# *   `mnist_*.csv` is a small sample of the
#     [MNIST database](https://en.wikipedia.org/wiki/MNIST_database), which is
#     described at: http://yann.lecun.com/exdb/mnist/
#
# *   `anscombe.json` contains a copy of
#     [Anscombe's quartet](https://en.wikipedia.org/wiki/Anscombe%27s_quartet); it
#     was originally described in
#
#     Anscombe, F. J. (1973). 'Graphs in Statistical Analysis'. American
#     Statistician. 27 (1): 17-21. JSTOR 2682899.
#
#     and our copy was prepared by the
#     [vega_datasets library](https://github.com/altair-viz/vega_datasets/blob/4f67bdaad10f45e3549984e17e1b3088c731503d/vega_datasets/_data/anscombe.json).

# %%
# %env
# Out:
# {'SHELL': '/bin/bash',
#  'COLAB_JUPYTER_TRANSPORT': 'ipc',
#  'CGROUP_MEMORY_EVENTS': '/sys/fs/cgroup/memory.events /var/colab/cgroup/jupyter-children/memory.events',
#  'VM_GCE_METADATA_HOST': '169.254.169.253',
#  'MODEL_PROXY_HOST': 'https://mp.kaggle.net',
#  'HOSTNAME': 'cddca2aa7dfd',
#  'LANGUAGE': 'en_US',
#  'TBE_RUNTIME_ADDR': '172.28.0.1:8011',
#  'GCE_METADATA_TIMEOUT': '3',
#  'COLAB_JUPYTER_IP': '172.28.0.12',
#  'COLAB_LANGUAGE_SERVER_PROXY_ROOT_URL': 'http://172.28.0.1:8013/',
#  'KMP_LISTEN_PORT': '6000',
#  'TF_FORCE_GPU_ALLOW_GROWTH': 'true',
#  'ENV': '/root/.bashrc',
#  'PWD': '/',
#  'TBE_EPHEM_CREDS_ADDR': '172.28.0.1:8009',
#  'COLAB_LANGUAGE_SERVER_PROXY_REQUEST_TIMEOUT': '30s',
#  'TBE_CREDS_ADDR': '172.28.0.1:8008',
#  'COLAB_JUPYTER_TOKEN': '<hidden>',
#  'LAST_FORCED_REBUILD': '20250623',
#  'TCLLIBPATH': '/usr/share/tcltk/tcllib1.20',
#  'COLAB_KERNEL_MANAGER_PROXY_HOST': '172.28.0.12',
#  'UV_BUILD_CONSTRAINT': '',
#  'COLAB_WARMUP_DEFAULTS': '1',
# ...

# %% [markdown]
# Understanding Data Types in Python

# %%
import numpy as np

# %%
np.array([1, 4, 2, 5, 3])
# Out:
# array([1, 4, 2, 5, 3])

# %%
np.array([3.14, 4, 2, 3])
# Out:
# array([3.14, 4.  , 2.  , 3.  ])

# %%
np.array([1, 2, 3, 4], dtype='float32')
# Out:
# array([1., 2., 3., 4.], dtype=float32)

# %%
np.array([1, 2, 3, 4], dtype='int')
# Out:
# array([1, 2, 3, 4])

# %%
np.array([range(i, i + 3) for i in [2, 4, 6]])
# Out:
# array([[2, 3, 4],
#        [4, 5, 6],
#        [6, 7, 8]])

# %%
import numpy as np

# %%
x1 = np.random.randint(10, size=6)  # One-dimensional array
x2 = np.random.randint(10, size=(3, 4))  # Two-dimensional array
x3 = np.random.randint(10, size=(3, 4, 5))  # Three-dimensional array

# %%
print("x3 ndim: ", x3.ndim) # La propiedad ndim nos dice el número de dimensiones
print("x3 shape:", x3.shape)
print("x3 size: ", x3.size)
# Out:
# x3 ndim:  3
# x3 shape: (3, 4, 5)
# x3 size:  60

# %%
print(x2.dtype) # Nos dice el tipo de dato
# Out:
# int64

# %%
print("itemsize:", x3.itemsize, "bytes")
print("nbytes:", x3.nbytes, "bytes")
# Out:
# itemsize: 8 bytes
# nbytes: 480 bytes

# %% [markdown]
# Array Indexing: Accessing Single Elements

# %%
x1
# Out:
# array([6, 0, 6, 5, 9, 6])

# %%
x1[0] # Colocamos el índice del elemento a extraer, en este caso el primer elemento tienen el indice 0
# Out:
# np.int64(6)

# %%
x1[4]
# Out:
# np.int64(9)

# %%
x1[-1] # Nos regresa el último elemento del ndarray
# Out:
# np.int64(6)

# %%
x2
# Out:
# array([[7, 5, 5, 2],
#        [8, 3, 3, 2],
#        [6, 6, 2, 3]])

# %%
x2[0,0]
# Out:
# np.int64(7)

# %%
x2[0,2]
# Out:
# np.int64(5)

# %%
x2[0,0] = 12 # Asignar un nuevo valor al renglón 0 columna 0
x2
# Out:
# array([[12,  5,  5,  2],
#        [ 8,  3,  3,  2],
#        [ 6,  6,  2,  3]])

# %% [markdown]
# #### Estadística básica

# %% [markdown]
# Media (Mean)

# %%
data = np.array([1, 2, 3, 4, 5])
media = np.mean(data)
print(media)
# Out:
# 3.0

# %% [markdown]
# Promedio (Average) y Promedio Ponderado

# %%
data = np.array([1, 2, 3, 4, 5])
weights = np.array([1, 2, 3, 4, 5])
promedio = np.average(data)
promedio_ponderado = np.average(data, weights=weights)

# %%
print(promedio)
print(promedio_ponderado)
# Out:
# 3.0
# 3.6666666666666665

# %% [markdown]
# Mediana

# %%
mediana = np.median(data)
print (mediana)
# Out:
# 3.0

# %% [markdown]
# Varianza y Desviación Estándar

# %%
varianza = np.var(data)
desviacion = np.std(data)

# %%
print (varianza)
print (desviacion)
# Out:
# 2.0
# 1.4142135623730951

# %% [markdown]
# Generación de Datos Aleatorios

# %%
muestra = np.random.normal(0, 1, 1000)
print(np.mean(muestra), np.std(muestra))
# Out:
# 0.026968808803756825 0.977237531074634

# %% [markdown]
# Correlación

# %%
corr = np.corrcoef([1,2,3], [1,5,7])
corr
# Out:
# array([[1.        , 0.98198051],
#        [0.98198051, 1.        ]])
